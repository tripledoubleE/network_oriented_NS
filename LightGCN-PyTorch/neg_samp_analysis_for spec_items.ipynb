# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('/home/ece/Desktop/Negative_Sampling/LightGCN-PyTorch/data/lastfm/all_data.csv', header=None)
df = df.rename(columns={1:'users', 2:'items'})
df = df[['users', 'items']]

# %%
df
# Out:
#        users  items
# 0          0      1
# 1        424   4076
# 2       1311   1574
# 3       1671    410
# 4        997   1686
# ...      ...    ...
# 52664   1604   2809
# 52665    299   2498
# 52666     22    575
# 52667    915    275
# 52668   1359   4028
#
# [52669 rows x 2 columns]

# %%
df.to_csv('/home/ece/Desktop/Negative_Sampling/LightGCN-PyTorch/biparitite_graph.csv', index=False)

# %%
freq_table = df['items'].value_counts()

# %%
freq_table
# Out:
# 275     100
# 325      98
# 102      97
# 438      96
# 182      96
#        ...
# 3618      3
# 2084      3
# 1773      3
# 2563      3
# 3736      3
# Name: items, Length: 4489, dtype: int64

# %%
freq_table.describe()
# Out:
# count    4489.000000
# mean       11.732903
# std        15.548332
# min         3.000000
# 25%         4.000000
# 50%         6.000000
# 75%        12.000000
# max       100.000000
# Name: items, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar(freq_table.index, freq_table.values)
plt.xlabel('items')
plt.ylabel('Frequency')
plt.title('Frequency Distribution')
plt.show()

# %% [markdown]
# #### En cok yakalanamayan itemlar (not in pred)

# %%
df_731 = df.loc[df['items'] == 731]
df_731
# Out:
#        users  items
# 1401     681    731
# 1527    1004    731
# 1970    1292    731
# 5550    1070    731
# 7854      57    731
# 9663     427    731
# 10013    600    731
# 15207    283    731
# 15628    156    731
# 16858    817    731
# 19188    502    731
# 20276    838    731
# 22405   1777    731
# 23097   1341    731
# 24350    149    731
# 24927     31    731
# 28966    892    731
# 29352    459    731
# 29522   1854    731
# 32483     71    731
# 33264   1698    731
# 35538    577    731
# 35704    465    731
# 39275   1029    731
# 40196   1754    731
# 40564   1181    731
# 41425    468    731
# 43126    905    731
# 46923    651    731
# 47471    794    731
# 51503   1851    731

# %%
df_319 = df.loc[df['items'] == 319]
df_319
# Out:
#        users  items
# 2510    1706    319
# 3604    1634    319
# 4839    1873    319
# 5461     550    319
# 6649    1360    319
# 8860     890    319
# 9610     188    319
# 12616   1640    319
# 13439     11    319
# 16692    863    319
# 18057   1455    319
# 18390    834    319
# 20526   1504    319
# 25251   1586    319
# 27293   1408    319
# 29150   1093    319
# 30611   1037    319
# 31854   1398    319
# 36978   1514    319
# 38523   1052    319
# 41103    109    319
# 43785   1074    319
# 44707   1327    319
# 44807    588    319
# 47816   1000    319

# %%
df_437 = df.loc[df['items'] == 437]
df_437
# Out:
#        users  items
# 853     1150    437
# 2251    1291    437
# 3046    1639    437
# 3384    1519    437
# 3665    1777    437
# ...      ...    ...
# 49191   1395    437
# 49536   1224    437
# 50767   1522    437
# 51574   1439    437
# 51744    808    437
#
# [61 rows x 2 columns]

# %%
df_828 = df.loc[df['items'] == 828]
df_828
# Out:
#        users  items
# 86       392    828
# 236      906    828
# 571       89    828
# 1107    1319    828
# 1898     260    828
# ...      ...    ...
# 48513    520    828
# 48910    340    828
# 50063   1298    828
# 52305   1834    828
# 52505   1262    828
#
# [91 rows x 2 columns]

# %%
df_298 = df.loc[df['items'] == 298]
df_298
# Out:
#        users  items
# 1322     875    298
# 3202     811    298
# 3872     988    298
# 4566    1665    298
# 5168    1853    298
# 6599     634    298
# 7990    1461    298
# 9972    1863    298
# 11013   1686    298
# 11772   1447    298
# 12593   1872    298
# 15282   1577    298
# 15663    285    298
# 18777   1401    298
# 20382    134    298
# 21245   1386    298
# 22372    397    298
# 24114    927    298
# 25711    487    298
# 25915    131    298
# 26619   1765    298
# 26787     11    298
# 27213   1737    298
# 27277    155    298
# 31324    838    298
# 31598   1396    298
# 31635    484    298
# 34459    863    298
# 35514   1449    298
# 35680   1802    298
# 38185    667    298
# 38243    521    298
# 41369   1601    298
# 42306   1806    298
# 44361    473    298
# 44789    351    298
# 45604    377    298
# 46634   1261    298

# %%
df_582 = df.loc[df['items'] == 582]
df_582
# Out:
#        users  items
# 1284    1437    582
# 2106     939    582
# 2769    1392    582
# 2986     229    582
# 3497    1427    582
# ...      ...    ...
# 49180   1592    582
# 50916   1125    582
# 51310   1484    582
# 52478   1083    582
# 52630   1870    582
#
# [67 rows x 2 columns]

# %%
intersection = set(list(df_319.users)).intersection(list(df_298.users))
intersection
# Out:
# {11, 863}

# %%
intersection2 = set(list(df_319.users)).intersection(list(df_582.users))
intersection2
# Out:
# set()

# %%
# not in gt items
df_3887 = df.loc[df['items'] == 3887]
df_3887
# Out:
#        users  items
# 5607    1002   3887
# 19742    658   3887
# 22098    738   3887
# 32015    607   3887
# 39534   1517   3887

# %%
df_4393 = df.loc[df['items'] == 4393]
df_4393
# Out:
#        users  items
# 30853   1680   4393
# 39557   1096   4393
# 47246   1329   4393

# %%
df_4353 = df.loc[df['items'] == 4353]
df_4353
# Out:
#        users  items
# 4299    1796   4353
# 15040   1283   4353
# 43069   1111   4353

# %%
df_4347 = df.loc[df['items'] == 4347]
df_4347
# Out:
#        users  items
# 7902     424   4347
# 35629   1744   4347
# 46788   1030   4347
# 48227   1008   4347

# %%
df_749 = df.loc[df['items'] == 749]
df_749
# Out:
#        users  items
# 2485    1014    749
# 7423    1524    749
# 8015     133    749
# 15808   1736    749
# 27885   1300    749
# 35191     31    749
# 43914   1641    749
# 47147   1207    749
# 51142    599    749

# %%
df_965 = df.loc[df['items'] == 965]
df_965
# Out:
#        users  items
# 6346    1884    965
# 8794    1566    965
# 9124     655    965
# 21518    525    965
# 30957    255    965
# 37648   1208    965
# 37901     44    965
# 46489    132    965

# %%
df_4091 = df.loc[df['items'] == 4091]
df_4091
# Out:
#        users  items
# 14604   1785   4091
# 16460   1257   4091
# 26013   1387   4091
# 31003   1380   4091
# 41974    760   4091
# 42738   1270   4091
